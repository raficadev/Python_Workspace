# %%
# Importamos las bibliotecas necesarias para la importación de datos
import pandas as pd
import os

# %%
# Comprobamos en que directorio del sistema nos encontramos
os.getcwd()
# Out:
# '/Users/rafel/Documents/Python Data Science'

# %%
# Creamos la variable especificando la ruta a los datos que vamos a importar
peliculas = pd.read_csv("/Users/rafel/Documents/Python Data Science/99. Datos/RatingsPeliculas.csv")

# %%
# Comprobamos el número de filas
len(peliculas)
# Out:
# 559

# %%
# Comprobamos la estructura imprimiendo las 5 primeras filas
peliculas.head()
# Out:
#                 Pelicula    Genero  Ratings de Rotten Tomatoes %  \
# 0  (500) Days of Summer    Comedia                            87
# 1            10,000 B.C.  Aventura                             9
# 2             12 Rounds     Accion                            30
# 3              127 Hours  Aventura                            93
# 4              17 Again    Comedia                            55
#
#    Ratings de la Audience %  Presupuesto (millones USD)  Lanzamiento
# 0                        81                           8         2009
# 1                        44                         105         2008
# 2                        52                          20         2009
# 3                        84                          18         2010
# 4                        70                          20         2009

# %%
# Imprimimos el nombre de todas las columnas
peliculas.columns
# Out:
# Index(['Pelicula', 'Genero', 'Ratings de Rotten Tomatoes %',
#        'Ratings de la Audience %', 'Presupuesto (millones USD)',
#        'Lanzamiento'],
#       dtype='object')

# %%
# Renombramos las columnas
peliculas.columns = ["Pelicula", "Genero", "RatingsCriticos", "RatingsAudiencia", \
                     "PresupuestoMillones", "Año"]
peliculas.head()
# Out:
#                 Pelicula    Genero  RatingsCriticos  RatingsAudiencia  \
# 0  (500) Days of Summer    Comedia               87                81
# 1            10,000 B.C.  Aventura                9                44
# 2             12 Rounds     Accion               30                52
# 3              127 Hours  Aventura               93                84
# 4              17 Again    Comedia               55                70
#
#    PresupuestoMillones   Año
# 0                    8  2009
# 1                  105  2008
# 2                   20  2009
# 3                   18  2010
# 4                   20  2009

# %%
# Información general acerca del DataFrame, donde podemos comprobar el tipo de cada columna
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pelicula             559 non-null    object
#  1   Genero               559 non-null    object
#  2   RatingsCriticos      559 non-null    int64
#  3   RatingsAudiencia     559 non-null    int64
#  4   PresupuestoMillones  559 non-null    int64
#  5   Año                  559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
# Podemos comprobar que la columna "Año" no la queremos tratar de forma numérica, 
# y lo podemos ver de forma más clara en el siguiente ejemplo
peliculas.describe()
# Out:
#        RatingsCriticos  RatingsAudiencia  PresupuestoMillones          Año
# count       559.000000        559.000000           559.000000   559.000000
# mean         47.309481         58.744186            50.236136  2009.152057
# std          26.413091         16.826887            48.731817     1.362632
# min           0.000000          0.000000             0.000000  2007.000000
# 25%          25.000000         47.000000            20.000000  2008.000000
# 50%          46.000000         58.000000            35.000000  2009.000000
# 75%          70.000000         72.000000            65.000000  2010.000000
# max          97.000000         96.000000           300.000000  2011.000000

# %%
# Definimos las columnas deseadas como "category"
peliculas.Pelicula = peliculas.Pelicula.astype("category")
peliculas.Genero = peliculas.Genero.astype("category")
peliculas.Año = peliculas.Año.astype("category")

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pelicula             559 non-null    category
#  1   Genero               559 non-null    category
#  2   RatingsCriticos      559 non-null    int64
#  3   RatingsAudiencia     559 non-null    int64
#  4   PresupuestoMillones  559 non-null    int64
#  5   Año                  559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
# Al haber cambiado el tipo a categoria esto nos permite utilizar la siguiente función
peliculas.Genero.cat.categories
# Out:
# Index(['Accion', 'Aventura', 'Comedia', 'Drama', 'Romance', 'Suspenso',
#        'Terror'],
#       dtype='object')

# %%
# También veremos que la columna Años ya no aparece
peliculas.describe()
# Out:
#        RatingsCriticos  RatingsAudiencia  PresupuestoMillones
# count       559.000000        559.000000           559.000000
# mean         47.309481         58.744186            50.236136
# std          26.413091         16.826887            48.731817
# min           0.000000          0.000000             0.000000
# 25%          25.000000         47.000000            20.000000
# 50%          46.000000         58.000000            35.000000
# 75%          70.000000         72.000000            65.000000
# max          97.000000         96.000000           300.000000

# %% [markdown]
# ---

# %%
# Importamos las bibliotecas para crear las visualizaciones
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# jointplots
j = sns.jointplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia")

# %%
# Diagrama 1
j = sns.jointplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia", kind = "hex")

# %% [markdown]
# ---

# %%
# Histogramas
# Método usado anteriormente
m1 = sns.distplot(peliculas.RatingsAudiencia, bins = 30)

# %%
m2 = sns.distplot(peliculas.RatingsCriticos, bins = 30)

# %%
# Diagrama 2
n1 = plt.hist(peliculas.RatingsAudiencia, bins = 30)

# %%
# Diagrama 3
n2 = plt.hist(peliculas.RatingsCriticos, bins = 30)

# %% [markdown]
# Con los gráficos anteriores podemos comprobar como la puntuación de la audiencia se
# distribuye de forma uniforme, al ser más natural dada por las emociones generadas.
# Mientras que la puntuación de la crítica debe seguir unos criterios de evaluación,
# lo que conlleva una pérdida de naturalidad y una mayor distribución.

# %% [markdown]
# ---

# %%
# Histogramas Apilados
plt.hist(peliculas[peliculas.Genero == "Accion"].PresupuestoMillones, bins = 30)
plt.hist(peliculas[peliculas.Genero == "Drama"].PresupuestoMillones, bins = 30)
plt.hist(peliculas[peliculas.Genero == "Suspenso"].PresupuestoMillones, bins = 30)
plt.show()

# %%
# Creación de lista para apilar las barras
plt.hist([peliculas[peliculas.Genero == "Accion"].PresupuestoMillones, \
          peliculas[peliculas.Genero == "Drama"].PresupuestoMillones, \
          peliculas[peliculas.Genero == "Suspenso"].PresupuestoMillones], \
         bins = 30, stacked = True)
plt.show()

# %%
# Diagrama 4
# Iterar los géneros de forma automática
lista1 = list()
mis_etiquetas = list()

for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero == gen].PresupuestoMillones)
    mis_etiquetas.append(gen)
    
h = plt.hist(lista1, bins = 30, stacked = True, rwidth = 0.8, label = mis_etiquetas)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
# Gráfico KDE
vis1 = sns.lmplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia", \
                 fit_reg = False, hue = "Genero", height = 6, aspect = 1)

# %%
sns.set_style("darkgrid")
k1 = sns.kdeplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia", \
                 shade = True, cmap = "Reds")

# %% [markdown]
# ---

# %%
# Trabajando con subplots()
sns.set_style("dark")
k2 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsAudiencia")

# %%
k3 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsCriticos")

# %%
f, axes = plt.subplots(1, 2, figsize = (12,6), sharex = True, sharey = True)
k2 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsAudiencia", ax = axes[0])
k3 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsCriticos", ax = axes[1])
k2.set(xlim = (-50, 250))
# Out:
# [(-50.0, 250.0)]

# %% [markdown]
# ---

# %%
# Diagramas de Violín
z1 = sns.boxplot(data = peliculas, x = "Genero", y = "RatingsCriticos")

# %%
z2 = sns.violinplot(data = peliculas, x = "Genero", y = "RatingsCriticos")

# %%
w1 = sns.boxplot(data = peliculas[peliculas.Genero == "Drama"], x = "Año", y = "RatingsCriticos")

# %%
w2 = sns.violinplot(data = peliculas[peliculas.Genero == "Drama"], x = "Año", y = "RatingsCriticos")

# %% [markdown]
# ---

# %%
# Creando un FacetGrid
g = sns.FacetGrid(peliculas, row = "Genero", col = "Año", hue = "Genero")
kws = dict(s = 50, linewidth = 0.5, edgecolor = "black")
g.map(plt.scatter, "RatingsCriticos", "RatingsAudiencia", **kws)
plt.show()

# %%
# Podemos rellenarlo con cualquier tipo de gráfico
# Ejemplo con Histogramas
g = sns.FacetGrid(peliculas, row = "Genero", col = "Año", hue = "Genero")
g.map(plt.hist, "PresupuestoMillones")
plt.show()

# %% [markdown]
# ---

# %%
# Controlando ejes y agregando diagonales
# Diagrama 5
g = sns.FacetGrid(peliculas, row = "Genero", col = "Año", hue = "Genero")
kws = dict(s = 50, linewidth = 0.5, edgecolor = "black")
g.map(plt.scatter, "RatingsCriticos", "RatingsAudiencia", **kws)
g.set(xlim = (0, 100), ylim = (0, 100))

for ax in g.axes.flat:
    ax.plot((0, 100), (0, 100), c = "gray", ls = "--")    
g.add_legend()
plt.show()

# %% [markdown]
# ---

# %%
# Construyendo Dashboards
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2, 2, figsize = (15, 15))

k2 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsAudiencia", ax = axes[0, 0])

k3 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsCriticos", ax = axes[0, 1])

w2 = sns.violinplot(data = peliculas[peliculas.Genero == "Drama"], x = "Año", y = "RatingsCriticos", ax = axes[1, 0])

k1 = sns.kdeplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia", shade = True, cmap = "Reds", ax = axes[1, 1])

# Agregar una visualización que no está hecha en "sns"
# Realizar las siguientes modificaciones para esta visualización: n1 = plt.hist(peliculas.RatingsAudiencia, bins = 30)
# axes[1, 1].hist(peliculas.RatingsAudiencia, bins = 30)

k2.set(xlim = (-50, 250))
k3.set(xlim = (-50, 250))
plt.show()

# %% [markdown]
# ---

# %%
# Dar estilo a los Dashboards
sns.set_style("dark", {"axes.facecolor": "black"}) # withe, withegrid, dark, darkgrid, ticks
f, axes = plt.subplots(2, 2, figsize = (15, 15))

# Gráfico [0, 0]
k2 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsAudiencia", \
                  shade = True, cmap = "inferno", ax = axes[0, 0])
k2b =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsAudiencia", \
                  cmap = "cool", ax = axes[0, 0])

# Gráfico [0, 1]
k3 =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsCriticos", \
                  shade = True, cmap = "inferno", ax = axes[0, 1])
k3b =  sns.kdeplot(data = peliculas, x = "PresupuestoMillones", y = "RatingsCriticos", \
                  cmap = "cool", ax = axes[0, 1])

# Gráfico [1, 0]
w2 = sns.violinplot(data = peliculas, x = "Año", y = "RatingsCriticos", \
                    palette = "YlOrRd", ax = axes[1, 0])

# Gráfico [1, 1]
k1 = sns.kdeplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia", \
                 shade = True, cmap = "Blues_r", ax = axes[1, 1])
k1b = sns.kdeplot(data = peliculas, x = "RatingsCriticos", y = "RatingsAudiencia", \
                 cmap = "gist_gray_r", ax = axes[1, 1])

k2.set(xlim = (-50, 250))
k3.set(xlim = (-50, 250))
plt.show()

# %% [markdown]
# ---

# %%
# Cambios temáticos
sns.set_style("whitegrid")
lista1 = list()
mis_etiquetas = list()

for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero == gen].PresupuestoMillones)
    mis_etiquetas.append(gen)

fig, ax = plt.subplots(1, 1) # Creamos la figura donde irá el gráfico
fig.set_size_inches(11.7, 8.27) # Tamaño hoja dinA4
    
h = plt.hist(lista1, bins = 30, stacked = True, rwidth = 0.8, edgecolor = "none", label = mis_etiquetas)
plt.title("Distribución de Presupuestos para las Películas", \
          fontsize = 30, color = "Red", fontname = "Arial")
plt.ylabel("Número de Películas", fontsize = 20, color = "DarkBlue")
plt.xlabel("Presupuesto", fontsize = 20, color = "Green")
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.legend(shadow = True, prop = {"size": 15})
plt.show()
